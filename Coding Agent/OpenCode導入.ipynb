# %%
# zstdをインストールしてからOllamaを入れる
# !sudo apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh

import subprocess, time
subprocess.Popen(["ollama", "serve"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
time.sleep(5)

# 起動確認
# !ollama list
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 0s (2,884 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package zstd.
# ...

# %%
# GPU検出ツールをインストール
# !sudo apt-get install -y pciutils lshw

# OllamaサービスをGPU認識した状態で再起動
# !sudo systemctl restart ollama 2>/dev/null || true
import subprocess, time
subprocess.Popen(["ollama", "serve"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
time.sleep(5)

# GPU認識確認
# !nvidia-smi
# !ollama list
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpci3 pci.ids usb.ids
# The following NEW packages will be installed:
#   libpci3 lshw pci.ids pciutils usb.ids
# 0 upgraded, 5 newly installed, 0 to remove and 37 not upgraded.
# Need to get 883 kB of archives.
# After this operation, 3,256 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 pci.ids all 0.0~2022.01.22-1ubuntu0.1 [251 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpci3 amd64 1:3.7.0-6 [28.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 lshw amd64 02.19.git.2021.06.19.996aaad9c7-2build1 [321 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 pciutils amd64 1:3.7.0-6 [63.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 usb.ids all 2022.04.02-1 [219 kB]
# Fetched 883 kB in 1s (1,150 kB/s)
# ...

# %%
# !ollama pull qwen3:14b

# %%
modelfile = """FROM qwen3:14b
PARAMETER num_ctx 16384
"""
with open("/tmp/Modelfile", "w") as f:
    f.write(modelfile)

# !ollama create qwen3:14b-16k -f /tmp/Modelfile

# %%
# !pip install colab-xterm -q
# %load_ext colabxterm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 8.0 MB/s eta 0:00:00

# %%
# 古いOpenCodeを削除して再インストール
# !rm -rf ~/.local/bin/opencode ~/.opencode

# 正しいインストーラーで再インストール
# !curl -fsSL https://opencode.ai/install | bash

import os
os.environ["PATH"] = f"{os.environ['HOME']}/.opencode/bin:{os.environ['PATH']}"

# 確認
# !opencode --version
# Out:
# Installing opencode version: 1.2.3
# ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■ 100%
# Command already exists in /root/.bashrc, skipping write.
#
#                                  ▄
# █▀▀█ █▀▀█ █▀▀█ █▀▀▄ █▀▀▀ █▀▀█ █▀▀█ █▀▀█
# █░░█ █░░█ █▀▀▀ █░░█ █░░░ █░░█ █░░█ █▀▀▀
# ▀▀▀▀ █▀▀▀ ▀▀▀▀ ▀  ▀ ▀▀▀▀ ▀▀▀▀ ▀▀▀▀ ▀▀▀▀
#
#
# OpenCode includes free models, to start:
#
# cd <project>  # Open directory
# opencode      # Run command
#
# For more information visit https://opencode.ai/docs
#
#
# 1.2.3

# %%
import json, os

config = {
    "$schema": "https://opencode.ai/config.json",
    "model": "qwen3:14b-16k",
    "provider": {
        "ollama": {
            "npm": "@ai-sdk/openai-compatible",
            "name": "Ollama (local)",
            "options": {
                "baseURL": "http://localhost:11434/v1"
            },
            "models": {
                "qwen3:14b-16k": {
                    "name": "Qwen3 14B (16k context)",
                    "tools": True
                }
            }
        }
    }
}

os.makedirs(os.path.expanduser("~/.config/opencode"), exist_ok=True)
config_path = os.path.expanduser("~/.config/opencode/opencode.json")
with open(config_path, "w") as f:
    json.dump(config, f, indent=2)

# 確認
with open(config_path) as f:
    print(f.read())
# Out:
# {
#   "$schema": "https://opencode.ai/config.json",
#   "model": "qwen3:14b-16k",
#   "provider": {
#     "ollama": {
#       "npm": "@ai-sdk/openai-compatible",
#       "name": "Ollama (local)",
#       "options": {
#         "baseURL": "http://localhost:11434/v1"
#       },
#       "models": {
#         "qwen3:14b-16k": {
#           "name": "Qwen3 14B (16k context)",
#           "tools": true
#         }
#       }
#     }
#   }
# }

# %%
import subprocess, time
subprocess.Popen(["ollama", "serve"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
time.sleep(5)
# !ollama list
# Out:
# NAME             ID              SIZE      MODIFIED
# qwen3:14b-16k    d19004a0061d    9.3 GB    17 minutes ago
# qwen3:14b        bdbd181c33f2    9.3 GB    18 minutes ago

# %%
import json, os

config = {
    "$schema": "https://opencode.ai/config.json",
    "model": "ollama/qwen3:14b-16k",
    "provider": {
        "ollama": {
            "npm": "@ai-sdk/openai-compatible",
            "options": {
                "baseURL": "http://localhost:11434/v1"
            },
            "models": {
                "qwen3:14b-16k": {
                    "name": "Qwen3 14B (16k context)",
                    "tools": True
                }
            }
        }
    }
}

config_path = os.path.expanduser("~/.config/opencode/opencode.json")
with open(config_path, "w") as f:
    json.dump(config, f, indent=2)

print("設定完了！")
# !cat ~/.config/opencode/opencode.json
# Out:
# 設定完了！
# {
#   "$schema": "https://opencode.ai/config.json",
#   "model": "ollama/qwen3:14b-16k",
#   "provider": {
#     "ollama": {
#       "npm": "@ai-sdk/openai-compatible",
#       "options": {
#         "baseURL": "http://localhost:11434/v1"
#       },
#       "models": {
#         "qwen3:14b-16k": {
#           "name": "Qwen3 14B (16k context)",
#           "tools": true
#         }
#       }
#     }
#   }
# }

# %%
import os
os.environ["PATH"] = f"{os.environ['HOME']}/.opencode/bin:{os.environ['PATH']}"
# !opencode run "フィボナッチ数列を出力するPythonスクリプトを作成してください"
# Out:
# > build · qwen3:14b-16k
#
#   🔍 Resolving [1/1]   🚚 pyright [7/6]   🚚 pyright [7/6]   🔒 Saving lockfile... ← Write fibonacci.py
# Wrote file successfully.
#
# The script has been written and saved as `fibonacci.py` in the current directory. You can run it using `python /content/fibonacci.py`.

# %%
skill_md = """# Python コーディングスキル

## ルール
- 全ての関数には必ず日本語のdocstringをつける
- 変数名は英語、コメントは日本語で書く
- 関数の最後に使用例をprint文で示す
"""

with open("/content/SKILL.md", "w") as f:
    f.write(skill_md)

print("SKILL.md作成完了！")
# !cat /content/SKILL.md
# Out:
# SKILL.md作成完了！
# # Python コーディングスキル
#
# ## ルール
# - 全ての関数には必ず日本語のdocstringをつける
# - 変数名は英語、コメントは日本語で書く
# - 関数の最後に使用例をprint文で示す

# %%
import os
os.environ["PATH"] = f"{os.environ['HOME']}/.opencode/bin:{os.environ['PATH']}"

# !opencode run "SKILL.mdのルールに従って、素数を判定するPython関数を作成してください" --context /content/SKILL.md
# Out:
# opencode run [message..]
#
# run opencode with a message
#
# Positionals:
#   message  message to send                                                     [array] [default: []]
#
# Options:
#   -h, --help        show help                                                              [boolean]
#   -v, --version     show version number                                                    [boolean]
#       --print-logs  print logs to stderr                                                   [boolean]
#       --log-level   log level                   [string] [choices: "DEBUG", "INFO", "WARN", "ERROR"]
#       --command     the command to run, use message for args                                [string]
#   -c, --continue    continue the last session                                              [boolean]
#   -s, --session     session id to continue                                                  [string]
# ...

# %%
skill_md = """# Python コーディングスキル

## ルール
- 全ての関数には必ず日本語のdocstringをつける
- 変数名は英語、コメントは日本語で書く
- 関数の最後に使用例をprint文で示す
"""

with open("/content/SKILL.md", "w") as f:
    f.write(skill_md)

print("SKILL.md作成完了！")
# !cat /content/SKILL.md
# Out:
# SKILL.md作成完了！
# # Python コーディングスキル
#
# ## ルール
# - 全ての関数には必ず日本語のdocstringをつける
# - 変数名は英語、コメントは日本語で書く
# - 関数の最後に使用例をprint文で示す

# %%
import os
os.environ["PATH"] = f"{os.environ['HOME']}/.opencode/bin:{os.environ['PATH']}"

# !opencode run "添付したSKILL.mdのルールに従って、素数を判定するPython関数を作成してください" -f /content/SKILL.md
# Out:
# > build · qwen3:14b-16k
#
# ← Write is_prime.py
# Wrote file successfully.
#
# The function `is_prime` has been created in the file `is_prime.py` following the rules specified in SKILL.md. It includes a Japanese docstring, uses English variable names, and provides example usage with print statements.
